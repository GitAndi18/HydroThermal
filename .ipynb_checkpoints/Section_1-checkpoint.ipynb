# %% [markdown]
# # Section_1

# %%
<img src="Fluss2.jpg" width="200" height="500">
# Out:
#   Cell In[7], line 1
#     <img src="Fluss2.jpg" width="200" height="500">
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# <img src="Fluss2.jpg"
#      align="left"
#      width="500" />

# %%
<div>
<img src="attachment:Fluss2.jpg" width="500">
</div>
# Out:
#   Cell In[9], line 1
#     <div>
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# <img src="attachment:Fluss2.jpg" width="400">

# %% [markdown]
# ```{image} Fluss2.jpg
# :alt: fish
# :class: bg-primary mb-1
# :width: 400px
# :align: center
# ```

# %%
import os

os.environ['MY_API_KEY'] = 'JuBooks'

# Access the environment variable later in your code
api_key = os.environ['MY_API_KEY']

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\beck\miniforge3\envs\Astro24\python.exe

# %% [markdown]
# ![Fluss3.jpg](attachment:521a15cf-bd90-47ff-b5a9-eb7713b193a9.jpg)

# %% [markdown]
# <div>
#     <img src="attachment:Fluss1.png" width="500"/>
# </div>

# %% [markdown]
# ![Fluss1.PNG](attachment:83484c39-ce5f-4344-a010-fd9ae5093ad5.PNG)

# %%
<div style="width: 200px;">![Fluss1.png](attachment:Fluss1.png)</div>
<img src="attachment:Fluss1.png" width="200">
# Out:
#   Cell In[21], line 1
#     <div style="width: 200px;">![Fluss1.png](attachment:Fluss1.png)</div>
#     ^
# SyntaxError: invalid syntax

# %%
<nop/> <div style="width: 200px;">![foo.svg](attachment:Fluss1.png)</div>
# Out:
#   Cell In[22], line 1
#     <nop/> <div style="width: 200px;">![foo.svg](attachment:Fluss1.png)</div>
#     ^
# SyntaxError: invalid syntax
